# %%
import os
import pandas as pd
import collections
import pickle
#import cPickle
import _pickle as cPickle

import scipy
from scipy import sparse
import numpy as np

import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from sklearn.cluster import KMeans
from sklearn.externals import joblib
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
from sklearn.pipeline import make_pipeline
from sklearn import metrics
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

import numpy as np
import random

# %matplotlib inline
import matplotlib.pyplot as plt

import seaborn as sns

import nltk
import nltk.data
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk import word_tokenize,sent_tokenize

import re
import string
import time
import codecs
from Bio import Medline

import gensim
from gensim import corpora, models, similarities
from gensim.models.doc2vec import LabeledSentence
from gensim.models import Doc2Vec, Word2Vec, CoherenceModel
from gensim.summarization import summarize

from collections import defaultdict

import pyLDAvis.gensim

import GapStatistics
import time

import bokeh

# %%
# Configurations and Variable Definitions

# %%
# Configuration: Data file name (it should be placed in the same ditrectory as the notebook file)
DATA_FILE = DATA_FILE = '/data/pubmedtext.txt'
#test variables
# test_pmid = '27179337'
test_pmid = '28324318'

# %%
# constant variables
CLEANED_ABSTRACT_COL = 'cleaned_abstract'
SUMMARY_ABSTRACT_COL = 'summary_abstract'
CLEANED_MINIMAL_ABSTRACT_COL = 'cleaned_minimal_abstract'
TOKENIZED_CLEAN_ABS_COL = 'tokenized_c_abstract'
TOKENIZED_RAW_ABS_COL = 'tokenized_r_abstract'
TOKEN_COUNT_RAW_ABS_COL = 'token_count_r_abstract'
TOKEN_COUNT_CLEAN_ABS_COL = 'token_count_c_abstract'
TOKEN_COUNT_Unq_CLEAN_ABS_COL = 'token_count_unq_c_abstract'

# %%
# Input File Processing

# %%
#Dictionary of medline terms: https://www.nlm.nih.gov/bsd/mms/medlineelements.html
#Note that this differs from above by removing grants and affiliations in an effort to minimize exceptions
def read_medline_data_raw(filename):
    recs = Medline.parse(open(filename, 'r'))
    text = pd.DataFrame(columns = ["pmid", "articletitle", "journaltitle", "abstract"])
    count = 0
    for rec in recs:
        try:
            pmid = rec['PMID']
            atitle = rec["TI"]
            jtitle = rec["JT"]
            pubdate = rec["DP"]
            abstr = rec["AB"]
            text = text.append(pd.DataFrame([[pmid,atitle, jtitle,pubdate, abstr]],
                columns=["pmid", "articletitle", "journaltitle", "pubdate", "abstract"]),ignore_index=True, verify_integrity=True)            
        except:
            pass
    text.set_index(text.pmid)
    return text

# %%
# get the Data file path

print("Cell started at: " + time.strftime("%c"))
try:
    approot = os.path.dirname(os.path.realpath('__file__'))
except NameError:  # if it is the main script, not a module
    import sys
    approot = os.path.dirname(os.path.abspath(sys.argv[0]))
DATA_PATH = approot + DATA_FILE

# Read in MEDLINE formatted text
# %time papers = read_medline_data_raw(DATA_PATH)
papers.to_pickle('data/papers_pain_EngFilter_6_5_2017_raw_oct17update')
papers.to_csv('data/papers_pain_EngFilter_6_5_2017_raw_oct17update.csv')
print("Cell completed at: " + time.strftime("%c"))
# Out:
# Cell started at: Fri May 18 09:05:52 2018
# CPU times: user 94.5 ms, sys: 80 µs, total: 94.5 ms
# Wall time: 93.8 ms
# Cell completed at: Fri May 18 09:05:52 2018

# %%
papers = pd.read_pickle('data/papers_pain_EngFilter_6_5_2017_raw_oct17update')

# %%
papers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 5 columns):
# abstract        61 non-null object
# articletitle    61 non-null object
# journaltitle    61 non-null object
# pmid            61 non-null object
# pubdate         61 non-null object
# dtypes: object(5)
# memory usage: 2.5+ KB

# %%
pubdatevalues = papers.pubdate.unique()
#pubdatevalues.tofile("pubdatevalues.csv", sep=',') Examine range of pubdates manually in csv

# %%
papers['pubdate_dtformat'] = pd.to_datetime(papers.pubdate, format='%Y', exact=False)
papers['pubyear'] = pd.DatetimeIndex(papers['pubdate_dtformat']).year
papers=papers.drop('pubdate_dtformat', axis=1)

# %%
papers.tail(10)
# Out:
#                                              abstract  \
# 51  Non-steroidal anti-inflammatory drugs (NSAIDs)...
# 52  We investigated the changes in characteristics...
# 53  INTRODUCTION: Flupirtine, a nonopioid analgesi...
# 54  Post-herpetic neuralgia means pain which occur...
# 55  Antipsychotic drugs are the clinical standard ...
# 56  BACKGROUND: Sex, race, and age disparities in ...
# 57  BACKGROUND: Even though the use of a 25 gauge ...
# 58  PURPOSE: We analyzed variables associated with...
# 59  PURPOSE: To correlate computed tomography (CT)...
# 60  Rheumatoid arthritis (RA) is one of the inflam...
#
#                                          articletitle  \
# 51  Anti-inflammatory and antinociceptive activiti...
# 52  Expression of inflammatory and apoptosis facto...
# 53  Efficacy and tolerability of flupirtine in sub...
# 54  Modified Jaipur block for the treatment of pos...
# 55  Dynamic regulation of dopamine and serotonin r...
# 56  Patient demographic characteristics and facial...
# 57  Comparison of post-dural puncture headache and...
# 58  Predictors of long-term toxicity using three-d...
# 59  Correlation of computed tomography imaging fea...
# 60  The antinociceptive efficacy of HWTX-I epidura...
#
#                                          journaltitle      pmid      pubdate  \
# 51                   International immunopharmacology  21855654     2011 Nov
# 52                   International immunopharmacology  21821152     2011 Nov
# 53  International journal of clinical pharmacology...  22011688     2011 Nov
# 54               International journal of dermatology  22004501     2011 Nov
# 55  The international journal of neuropsychopharma...  21281560     2011 Nov
# 56           International journal of nursing studies  21596378     2011 Nov
# 57           International journal of nursing studies  21561619     2011 Nov
# 58  International journal of radiation oncology, b...  20933342  2011 Nov 01
# 59  International journal of radiation oncology, b...  20889265  2011 Nov 01
# 60           International journal of sports medicine  22052031     2011 Nov
#
#     pubyear
# 51     2011
# 52     2011
# 53     2011
# 54     2011
# 55     2011
# 56     2011
# 57     2011
# 58     2011
# 59     2011
# 60     2011

# %%
papers.loc[papers['pubdate']=='2011 Nov']
# Out:
#                                              abstract  \
# 0   OBJECTIVE: To define the value of multislice c...
# 1   OBJECTIVES: To assess the feasibility of T2 ma...
# 2   Intraosseous lipoma is an uncommon mesenchymal...
# 3   OBJECTIVE: Aim of the present work is to asses...
# 4   PURPOSE: There are few prospective studies on ...
# 5   INTRODUCTION: Chronic pain has an impact on ps...
# 6   PURPOSE: TNFalpha is an inflammatory mediator ...
# 7   It is becoming increasingly evident that peopl...
# 8   AIMS: Gastrointestinal symptoms such as pain, ...
# 9   BACKGROUND: The clinical picture of pituitary ...
# 10  INTRODUCTION: In early 2011, the FDA gave appr...
# 11  Hereditary angioedema is a relatively rare gen...
# 12  In acute and chronic pain, the objective of ph...
# 13  There is a huge unmet need for novel medicines...
# 14  Human pain biomarkers are based on standardize...
# 15  Trigeminal neuralgia (TN) and persistent idiop...
# 19  Patients who continue to suffer from severe an...
# 26  BACKGROUND & AIMS: A randomized trial that com...
# 27  BACKGROUND & AIMS: Although proteases control ...
# 28  BACKGROUND & AIMS: The intestinal microbiomes ...
# 31  Functional gastrointestinal disorders (FGIDs) ...
# 32  OBJECTIVE: In patients with painful chronic pa...
# 33  INTRODUCTION: Unexplained chest pain is potent...
# 34  BACKGROUND: Recent evidence suggests that auto...
# 35  Haemophilia patients experience acute pain dur...
# 36  The authors describe a unique presentation of ...
# 37  BACKGROUND: Minimally invasive video-assisted ...
# 40  UNLABELLED: Many children consider getting a n...
# 43  Naproxen is a non-steroidal anti-inflammatory ...
# 44  BACKGROUND: Endometriosis is the most common g...
# 47  Patients over 65 years of age with suspected h...
# 48  INTRODUCTION: Patients with orthopaedic trauma...
# 49  Psychological factors are capable of influenci...
# 51  Non-steroidal anti-inflammatory drugs (NSAIDs)...
# 52  We investigated the changes in characteristics...
# 53  INTRODUCTION: Flupirtine, a nonopioid analgesi...
# 54  Post-herpetic neuralgia means pain which occur...
# 55  Antipsychotic drugs are the clinical standard ...
# 56  BACKGROUND: Sex, race, and age disparities in ...
# 57  BACKGROUND: Even though the use of a 25 gauge ...
# 60  Rheumatoid arthritis (RA) is one of the inflam...
#
#                                          articletitle  \
# 0   Value of multislice computed tomography in the...
# 1   Quantitative in vivo MRI evaluation of lumbar ...
# 2   Intraosseous lipoma presenting as a sphenoid s...
# 3   Combined occlusal and pharmacological therapy ...
# 4   Surgery improves pain, function and quality of...
# 5   The effect of repeated restraint stress in pai...
# 6   Etanercept attenuates pain-related behavior fo...
# 7   Effects of experimentally induced low back pai...
# 8   Effects of isolated hyperinsulinaemia on senso...
# 9          Hypopituitarism in a HIV affected patient.
# 10  Extended-release gabapentin in post-herpetic n...
# 11  Human pasteurized C1-inhibitor concentrate for...
# 12  Pharmacokinetic-pharmacodynamic modeling in ac...
# 13  Biologics: the next-generation therapeutics fo...
# 14  Optimizing the early phase development of new ...
# 15  Trigeminal neuralgia and persistent idiopathic...
# 19  Spinal cord stimulation for long-term treatmen...
# 26  Long-term outcomes of endoscopic vs surgical d...
# 27  Cathepsin S is activated during colitis and ca...
# 28  Gastrointestinal microbiome signatures of pedi...
# 31  The balancing act: endogenous modulation of pa...
# 32  Altered brain microstructure assessed by diffu...
# 33  Response of unexplained chest pain to proton p...
# 34  Frequency of pain crises in sickle cell anemia...
# 35  Assessment and management of pain in haemophil...
# 36    Celiac disease presenting as severe osteopenia.
# 37  Minimally invasive video-assisted thyroidectom...
# 40  Children's fear during procedural pain: prelim...
# 43  Naproxen-induced fixed drug eruption: a case r...
# 44  Catastrophizing: a predictor of persistent pai...
# 47  Fast-track care for patients with suspected hi...
# 48  Comparison of depressive symptoms during the e...
# 49  Psychological factors contributing to percepti...
# 51  Anti-inflammatory and antinociceptive activiti...
# 52  Expression of inflammatory and apoptosis facto...
# 53  Efficacy and tolerability of flupirtine in sub...
# 54  Modified Jaipur block for the treatment of pos...
# 55  Dynamic regulation of dopamine and serotonin r...
# 56  Patient demographic characteristics and facial...
# 57  Comparison of post-dural puncture headache and...
# 60  The antinociceptive efficacy of HWTX-I epidura...
#
#                                          journaltitle      pmid   pubdate  \
# 0                       European journal of radiology  20719444  2011 Nov
# 1                                  European radiology  21748388  2011 Nov
# 2   European review for medical and pharmacologica...  22195370  2011 Nov
# 3   European review for medical and pharmacologica...  22195362  2011 Nov
# 4   European spine journal : official publication ...  21706361  2011 Nov
# 5   European spine journal : official publication ...  21698480  2011 Nov
# 6   European spine journal : official publication ...  21633793  2011 Nov
# 7                         Experimental brain research  21952791  2011 Nov
# 8   Experimental and clinical endocrinology & diab...  22068552  2011 Nov
# 9   Experimental and clinical endocrinology & diab...  21922454  2011 Nov
# 10                  Expert opinion on pharmacotherapy  21942929  2011 Nov
# 11               Expert review of clinical immunology  22014012  2011 Nov
# 12             Expert review of clinical pharmacology  22111858  2011 Nov
# 13                 Expert review of neurotherapeutics  22014142  2011 Nov
# 14                 Expert review of neurotherapeutics  22014141  2011 Nov
# 15                 Expert review of neurotherapeutics  22014140  2011 Nov
# 19                                  Future cardiology  22050067  2011 Nov
# 26                                   Gastroenterology  21843494  2011 Nov
# 27                                   Gastroenterology  21802389  2011 Nov
# 28                                   Gastroenterology  21741921  2011 Nov
# 31                                                Gut  21768212  2011 Nov
# 32                                                Gut  21610272  2011 Nov
# 33                                                Gut  21508423  2011 Nov
# 34                                      Haematologica  21750084  2011 Nov
# 35  Haemophilia : the official journal of the Worl...  21645179  2011 Nov
# 36                             Hawaii medical journal  22162604  2011 Nov
# 37                                        Head & neck  21990219  2011 Nov
# 40  Health psychology : official journal of the Di...  21806301  2011 Nov
# 43                    Human & experimental toxicology  21357631  2011 Nov
# 44               Human reproduction (Oxford, England)  21900393  2011 Nov
# 47                                             Injury  21334620  2011 Nov
# 48                                             Injury  21310409  2011 Nov
# 49                                             Injury  20705288  2011 Nov
# 51                   International immunopharmacology  21855654  2011 Nov
# 52                   International immunopharmacology  21821152  2011 Nov
# 53  International journal of clinical pharmacology...  22011688  2011 Nov
# 54               International journal of dermatology  22004501  2011 Nov
# 55  The international journal of neuropsychopharma...  21281560  2011 Nov
# 56           International journal of nursing studies  21596378  2011 Nov
# 57           International journal of nursing studies  21561619  2011 Nov
# 60           International journal of sports medicine  22052031  2011 Nov
#
#     pubyear
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
# 5      2011
# 6      2011
# 7      2011
# 8      2011
# 9      2011
# 10     2011
# 11     2011
# 12     2011
# 13     2011
# 14     2011
# 15     2011
# 19     2011
# 26     2011
# 27     2011
# 28     2011
# 31     2011
# 32     2011
# 33     2011
# 34     2011
# 35     2011
# 36     2011
# 37     2011
# 40     2011
# 43     2011
# 44     2011
# 47     2011
# 48     2011
# 49     2011
# 51     2011
# 52     2011
# 53     2011
# 54     2011
# 55     2011
# 56     2011
# 57     2011
# 60     2011

# %%
papers.journaltitle.nunique()
# Out:
# 39

# %%
papers.to_pickle('data/papers_pain_EngFilter_6_5_2017_raw_oct17update_Mar18year')
papers = pd.read_pickle('data/papers_pain_EngFilter_6_5_2017_raw_oct17update_Mar18year')

# %%
# Text Cleanup & Tokenization

# %%
## Remove "all-caps:" section headers, punctuation marks, numbers, and option for words in all capital letters

# %%
# This function will use regular expressions to remove all:
#  (1) words/phrases in all caps followed by :, (if filter_all_caps = True, eveything all-caps will be removed)     
#  (2) numbers
#  (3) one letter words (such as n or p or other mathematical symbols)
#  (4) punctuation marks
# return value is the list of all filtered words (except for numbers), and the clean abstracts

# A utility function for flattening the lists
def flatten(l):
    for el in l:
        if isinstance(el, collections.Iterable) and not isinstance(el, str):
            for sub in flatten(el):
                yield sub
        else:
            yield el

# Filter text as described above            
def filterText(abstracts, filter_all_caps = False):    
    #define the regex pattern
    regex = re.compile('[%s]' % re.escape(re.sub('-', '', string.punctuation)))
    if filter_all_caps:
        pattern = regex.pattern + r"|\b[A-Z]{2,}|[0-9]+|\b\w\b|\d-\d|\W-\W|\s-\s" 
    else:
        pattern = regex.pattern + r"|(((\s|^)[A-Z]{2,}(,)*)*)(\s|^)(\b[A-Z]{2,}):|[0-9]+|\b\w\b|\d-\d|\W-\W|\s-\s" 
    
    #The list of all filtered words (except for numbers)
    # convert to a falttened set for faster results
    all_filtered_series = abstracts.apply(lambda d: re.findall(pattern, d))
    all_filtered = set(flatten(all_filtered_series.tolist()))
    non_digit_filtered = [y for y in all_filtered if not y.isdigit()]
    
    #remove whatever needs to be filtered
    abstracts = abstracts.apply(lambda d: re.sub(pattern, '', d))
    abstracts = abstracts.apply(lambda d: re.sub('\s-\s', '', d))
    
    return abstracts, non_digit_filtered
# Out:
# <input>:34: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:34: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:34: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:34: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:34: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:34: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:34: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:34: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:34: DeprecationWarning:
#
# invalid escape sequence \s
#
# <ipython-input-81-db72292a30c2>:34: DeprecationWarning:
#
# invalid escape sequence \s

# %%
## Remove stop words

# %%
# This function will replace all the stop words, it also gets rid of the whitespaces
def removeWord(text, stop_list):
    new_text = []
    
    #first convert to a list
    text_list = str.split(text)
    
    #check for stop words
    for x in text_list:
        if x not in stop_list:
            new_text.append(x)
    
    #convert back to string
    new_text_str = ' '.join(new_text)
    
    return new_text_str

# This function will remove stop words using NLTK stop word list
# It will return processed abstracts and stop word list
def removeStopWords(abstracts):         
    # use NLTK's default stop word list
    stop_set = set(stopwords.words('english'))
    
    # find all stop words and remove them
    abstracts = abstracts.apply(lambda d: removeWord(d, stop_set))
    
    return abstracts, stop_set

# %%
## Convert to lower case, tokenize

# %%
# This fuction will convert everything to lower-case
def changeToLowerCase(abstracts):  
    abstracts = abstracts.apply(lambda d: d.lower())
    return abstracts

# %%
# This function will tokenize all sentences
def tokenizeAbstracts(abstracts):  
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = abstracts.apply(lambda d: tokenizer.tokenize(d))
    return tokens

# %%
## Combine Preprocess Functions

# %%
def preprocessAbstracts(abstracts):    
    # Remove all-caps words, numbers, 1-letter words, punctuation marks 
    abstracts, filtered = filterText(abstracts, filter_all_caps= False)
    
    # conevrt to lower-case
    abstracts = changeToLowerCase(abstracts)
    
    # Remove stop words
    abstracts, stop_list = removeStopWords(abstracts)
    filtered = filtered + list(stop_list)
    
    # tokenize
    tokens = tokenizeAbstracts(abstracts)
    
    return abstracts, tokens, filtered

# %%
# This can be helpful for word2vec models that need minimal preprocessing
def minimallyPreprocessAbstracts(abstracts):
    #define the regex pattern
    regex = re.compile('[%s]' % re.escape(re.sub('-', '', string.punctuation)))
    pattern = regex.pattern + r"|[0-9.]+" 
    
    #remove whatever needs to be filtered
    abstracts = abstracts.apply(lambda d: re.sub(pattern, '#NUM', d))
    abstracts = abstracts.apply(lambda d: re.sub('\s-\s', '', d))
    return abstracts
# Out:
# <input>:9: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:9: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:9: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:9: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:9: DeprecationWarning:
#
# invalid escape sequence \s
#
# <input>:9: DeprecationWarning:
#
# invalid escape sequence \s
#
# <ipython-input-89-5f30a9706f1c>:9: DeprecationWarning:
#
# invalid escape sequence \s

# %%
## Apply preprocessing

# %%
# preprocess the abstracts
papers[CLEANED_ABSTRACT_COL], papers[TOKENIZED_CLEAN_ABS_COL], filtered = preprocessAbstracts(papers.abstract)
papers[CLEANED_MINIMAL_ABSTRACT_COL] = minimallyPreprocessAbstracts(papers.abstract)
# %time papers[TOKENIZED_RAW_ABS_COL] = tokenizeAbstracts(papers.abstract)
# pre-compute the token counts
papers[TOKEN_COUNT_CLEAN_ABS_COL] =papers[TOKENIZED_CLEAN_ABS_COL].map(lambda text: len(text))
papers[TOKEN_COUNT_RAW_ABS_COL] =papers[TOKENIZED_RAW_ABS_COL].map(lambda text: len(text))
papers[TOKEN_COUNT_Unq_CLEAN_ABS_COL] =papers[TOKENIZED_CLEAN_ABS_COL].map(lambda text: len(set(text)))
# Out:
# CPU times: user 4.96 ms, sys: 85 µs, total: 5.04 ms
# Wall time: 5.09 ms

# %%
#Show list of filtered terms
print(filtered)
# Out:
# ['', ' EXPERT', 'OPINION', 'CONCLUSION', 'PARTICIPANTS', ' ', 'LIMITATIONS', 'PATIENTS', 'METHOD', 'BACKGROUND', 'REPORT', ' PATIENTS AND', ' RESULTS AND', 'RESULTS', 'OBJECTIVE', 'BACKGROUND AND', ' AND', ' CASE', 'SETTINGS', ' METHODS AND', 'AIM', ' MATERIALS AND', ' DESIGN AND', 'METHODS', 'MATERIALS', 'AIMS', 'DESIGN', 'COVERED', 'PURPOSE', ' AREAS', 'INTRODUCTION', 'UNLABELLED', 'CONCLUSIONS', 'OBJECTIVES', 'more', 'we', 'themselves', 'where', 'he', 'by', 'ours', 'do', 'their', "you'd", "that'll", 'too', 'the', 'when', 'as', 'our', 'most', 'ma', 'up', 'under', 'no', 'a', "should've", 'once', 'for', "needn't", "shan't", 'hers', 'y', 'if', 'been', 'd', 'll', 'now', 'wasn', 'any', 'weren', 'just', 'ain', 'this', 'its', 'very', 'before', 'aren', "shouldn't", 'here', 's', 'how', 'nor', 'his', 'does', "hasn't", 'himself', "isn't", 'while', 'me', 'off', 'will', 'during', 'your', 're', 'of', 'in', 'don', 'shan', 'haven', 'shouldn', 'so', 'needn', 'or', 'at', 'not', 'yourself', 'won', 'further', 'herself', 'each', 'be', 'should', 'was', 'isn', "didn't", 'below', 'am', 'him', 'have', 'why', 'above', 'and', 'whom', 'couldn', 'into', 'doing', "you've", 'an', "don't", 'about', 'mustn', 'such', "wasn't", 'did', "mustn't", "aren't", 'were', 'all', 'after', 'didn', 'doesn', "you'll", 'which', 'own', 'same', "won't", 'on', 'm', 'with', 'to', 'through', 't', "hadn't", "haven't", 'over', 'her', 'out', 'itself', 'these', 'both', 'myself', "couldn't", 'some', 'hadn', 'from', 'them', 'down', "doesn't", 'there', 'few', "she's", 'it', 'yours', 'yourselves', 'i', 'my', 'wouldn', 'what', 'ourselves', 'than', "wouldn't", 'she', 'but', "weren't", 'having', 'then', "you're", 'is', 'they', 'against', 'between', 'those', 'again', "mightn't", 'until', 'has', 'had', 'other', 'can', 'hasn', 'theirs', 've', 'you', 'mightn', 'because', 'that', "it's", 'being', 'only', 'who', 'o', 'are']

# %%
papers.to_pickle('data/papapers_pain_EngFilter_6_5_2017_raw_preprocessed_oct17update_Mar18years')
# %time papers = pd.read_pickle('data/papapers_pain_EngFilter_6_5_2017_raw_preprocessed_oct17update_Mar18years')
# Out:
# CPU times: user 4.09 ms, sys: 1 µs, total: 4.09 ms
# Wall time: 4.09 ms

# %%
papers
# Out:
#                                              abstract  \
# 0   OBJECTIVE: To define the value of multislice c...
# 1   OBJECTIVES: To assess the feasibility of T2 ma...
# 2   Intraosseous lipoma is an uncommon mesenchymal...
# 3   OBJECTIVE: Aim of the present work is to asses...
# 4   PURPOSE: There are few prospective studies on ...
# 5   INTRODUCTION: Chronic pain has an impact on ps...
# 6   PURPOSE: TNFalpha is an inflammatory mediator ...
# 7   It is becoming increasingly evident that peopl...
# 8   AIMS: Gastrointestinal symptoms such as pain, ...
# 9   BACKGROUND: The clinical picture of pituitary ...
# 10  INTRODUCTION: In early 2011, the FDA gave appr...
# 11  Hereditary angioedema is a relatively rare gen...
# 12  In acute and chronic pain, the objective of ph...
# 13  There is a huge unmet need for novel medicines...
# 14  Human pain biomarkers are based on standardize...
# 15  Trigeminal neuralgia (TN) and persistent idiop...
# 16  Working with patients with different chronic p...
# 17  The Schwartz Report tracks emerging trends tha...
# 18  BACKGROUND AND OBJECTIVES: Prior research indi...
# 19  Patients who continue to suffer from severe an...
# 20  Most cases of Meckel's diverticulum (MD) are a...
# 21  The authors present two cases of mucocele of t...
# 22  Multicystic nephroma is a relatively rare tumo...
# 23  This is an unusual case of chronic abdominal p...
# 24  BACKGROUND: Indirect revascularization is a th...
# 25  Irritable bowel syndrome is chronic, uncontrol...
# 26  BACKGROUND & AIMS: A randomized trial that com...
# 27  BACKGROUND & AIMS: Although proteases control ...
# 28  BACKGROUND & AIMS: The intestinal microbiomes ...
# 29  Over the last 20 years, a great many innovatio...
# ..                                                ...
# 31  Functional gastrointestinal disorders (FGIDs) ...
# 32  OBJECTIVE: In patients with painful chronic pa...
# 33  INTRODUCTION: Unexplained chest pain is potent...
# 34  BACKGROUND: Recent evidence suggests that auto...
# 35  Haemophilia patients experience acute pain dur...
# 36  The authors describe a unique presentation of ...
# 37  BACKGROUND: Minimally invasive video-assisted ...
# 38  OBJECTIVES: To estimate the 1-year prevalence ...
# 39  BACKGROUND: Pattern-induced visual discomfort ...
# 40  UNLABELLED: Many children consider getting a n...
# 41  BACKGROUND: Recognition of sex differences in ...
# 42  BACKGROUND: Postural orthostatic tachycardia s...
# 43  Naproxen is a non-steroidal anti-inflammatory ...
# 44  BACKGROUND: Endometriosis is the most common g...
# 45  AIM: We examined whether activation of seroton...
# 46  BACKGROUND: Systemic sclerosis (SSc) is a mult...
# 47  Patients over 65 years of age with suspected h...
# 48  INTRODUCTION: Patients with orthopaedic trauma...
# 49  Psychological factors are capable of influenci...
# 50  PURPOSE: Although non-selective non-steroidal ...
# 51  Non-steroidal anti-inflammatory drugs (NSAIDs)...
# 52  We investigated the changes in characteristics...
# 53  INTRODUCTION: Flupirtine, a nonopioid analgesi...
# 54  Post-herpetic neuralgia means pain which occur...
# 55  Antipsychotic drugs are the clinical standard ...
# 56  BACKGROUND: Sex, race, and age disparities in ...
# 57  BACKGROUND: Even though the use of a 25 gauge ...
# 58  PURPOSE: We analyzed variables associated with...
# 59  PURPOSE: To correlate computed tomography (CT)...
# 60  Rheumatoid arthritis (RA) is one of the inflam...
#
#                                          articletitle  \
# 0   Value of multislice computed tomography in the...
# 1   Quantitative in vivo MRI evaluation of lumbar ...
# 2   Intraosseous lipoma presenting as a sphenoid s...
# 3   Combined occlusal and pharmacological therapy ...
# 4   Surgery improves pain, function and quality of...
# 5   The effect of repeated restraint stress in pai...
# 6   Etanercept attenuates pain-related behavior fo...
# 7   Effects of experimentally induced low back pai...
# 8   Effects of isolated hyperinsulinaemia on senso...
# 9          Hypopituitarism in a HIV affected patient.
# 10  Extended-release gabapentin in post-herpetic n...
# 11  Human pasteurized C1-inhibitor concentrate for...
# 12  Pharmacokinetic-pharmacodynamic modeling in ac...
# 13  Biologics: the next-generation therapeutics fo...
# 14  Optimizing the early phase development of new ...
# 15  Trigeminal neuralgia and persistent idiopathic...
# 16           Mirror box therapy: seeing is believing.
# 17  Meditation: the controlled psychophysical self...
# 18  An evaluation of family medicine residents' at...
# 19  Spinal cord stimulation for long-term treatmen...
# 20  Intestinal obstruction by giant Meckel's diver...
# 21        Mucocele of the appendix. Two case reports.
# 22  Multicystic nephroma in an elderly man. Case r...
# 23  Unusual case of abdominal pain following liver...
# 24  Transmyocardial laser revascularization. Perso...
# 25  The process of symptom control in Korean women...
# 26  Long-term outcomes of endoscopic vs surgical d...
# 27  Cathepsin S is activated during colitis and ca...
# 28  Gastrointestinal microbiome signatures of pedi...
# 29  Correlation of awareness and practice of worki...
# ..                                                ...
# 31  The balancing act: endogenous modulation of pa...
# 32  Altered brain microstructure assessed by diffu...
# 33  Response of unexplained chest pain to proton p...
# 34  Frequency of pain crises in sickle cell anemia...
# 35  Assessment and management of pain in haemophil...
# 36    Celiac disease presenting as severe osteopenia.
# 37  Minimally invasive video-assisted thyroidectom...
# 38  Headaches and academic performance in universi...
# 39  Interictal pattern-induced visual discomfort a...
# 40  Children's fear during procedural pain: prelim...
# 41  Sex differences in symptom presentation in acu...
# 42  Postural orthostatic tachycardia syndrome: dia...
# 43  Naproxen-induced fixed drug eruption: a case r...
# 44  Catastrophizing: a predictor of persistent pai...
# 45  Serotonergic descending inhibition in chronic ...
# 46  Dermatology life quality index in Thai patient...
# 47  Fast-track care for patients with suspected hi...
# 48  Comparison of depressive symptoms during the e...
# 49  Psychological factors contributing to percepti...
# 50  Efficacy and safety of parecoxib in the treatm...
# 51  Anti-inflammatory and antinociceptive activiti...
# 52  Expression of inflammatory and apoptosis facto...
# 53  Efficacy and tolerability of flupirtine in sub...
# 54  Modified Jaipur block for the treatment of pos...
# 55  Dynamic regulation of dopamine and serotonin r...
# 56  Patient demographic characteristics and facial...
# 57  Comparison of post-dural puncture headache and...
# 58  Predictors of long-term toxicity using three-d...
# 59  Correlation of computed tomography imaging fea...
# 60  The antinociceptive efficacy of HWTX-I epidura...
#
#                                          journaltitle      pmid       pubdate  \
# 0                       European journal of radiology  20719444      2011 Nov
# 1                                  European radiology  21748388      2011 Nov
# 2   European review for medical and pharmacologica...  22195370      2011 Nov
# 3   European review for medical and pharmacologica...  22195362      2011 Nov
# 4   European spine journal : official publication ...  21706361      2011 Nov
# 5   European spine journal : official publication ...  21698480      2011 Nov
# 6   European spine journal : official publication ...  21633793      2011 Nov
# 7                         Experimental brain research  21952791      2011 Nov
# 8   Experimental and clinical endocrinology & diab...  22068552      2011 Nov
# 9   Experimental and clinical endocrinology & diab...  21922454      2011 Nov
# 10                  Expert opinion on pharmacotherapy  21942929      2011 Nov
# 11               Expert review of clinical immunology  22014012      2011 Nov
# 12             Expert review of clinical pharmacology  22111858      2011 Nov
# 13                 Expert review of neurotherapeutics  22014142      2011 Nov
# 14                 Expert review of neurotherapeutics  22014141      2011 Nov
# 15                 Expert review of neurotherapeutics  22014140      2011 Nov
# 16                           Explore (New York, N.Y.)  22051561  2011 Nov-Dec
# 17                           Explore (New York, N.Y.)  22051558  2011 Nov-Dec
# 18                                    Family medicine  22076712  2011 Nov-Dec
# 19                                  Future cardiology  22050067      2011 Nov
# 20                           Il Giornale di chirurgia  22217379  2011 Nov-Dec
# 21                           Il Giornale di chirurgia  22217378  2011 Nov-Dec
# 22                           Il Giornale di chirurgia  22217377  2011 Nov-Dec
# 23                           Il Giornale di chirurgia  22217373  2011 Nov-Dec
# 24                           Il Giornale di chirurgia  22217372  2011 Nov-Dec
# 25  Gastroenterology nursing : the official journa...  22129795  2011 Nov-Dec
# 26                                   Gastroenterology  21843494      2011 Nov
# 27                                   Gastroenterology  21802389      2011 Nov
# 28                                   Gastroenterology  21741921      2011 Nov
# 29                                  General dentistry  22313919  2011 Nov-Dec
# ..                                                ...       ...           ...
# 31                                                Gut  21768212      2011 Nov
# 32                                                Gut  21610272      2011 Nov
# 33                                                Gut  21508423      2011 Nov
# 34                                      Haematologica  21750084      2011 Nov
# 35  Haemophilia : the official journal of the Worl...  21645179      2011 Nov
# 36                             Hawaii medical journal  22162604      2011 Nov
# 37                                        Head & neck  21990219      2011 Nov
# 38                                           Headache  22082420  2011 Nov-Dec
# 39                                           Headache  22050335  2011 Nov-Dec
# 40  Health psychology : official journal of the Di...  21806301      2011 Nov
# 41        Heart & lung : the journal of critical care  22000678  2011 Nov-Dec
# 42        Heart & lung : the journal of critical care  21329983  2011 Nov-Dec
# 43                    Human & experimental toxicology  21357631      2011 Nov
# 44               Human reproduction (Oxford, England)  21900393      2011 Nov
# 45                           In vivo (Athens, Greece)  22021700  2011 Nov-Dec
# 46  Indian journal of dermatology, venereology and...  22016275  2011 Nov-Dec
# 47                                             Injury  21334620      2011 Nov
# 48                                             Injury  21310409      2011 Nov
# 49                                             Injury  20705288      2011 Nov
# 50  International braz j urol : official journal o...  22234000  2011 Nov-Dec
# 51                   International immunopharmacology  21855654      2011 Nov
# 52                   International immunopharmacology  21821152      2011 Nov
# 53  International journal of clinical pharmacology...  22011688      2011 Nov
# 54               International journal of dermatology  22004501      2011 Nov
# 55  The international journal of neuropsychopharma...  21281560      2011 Nov
# 56           International journal of nursing studies  21596378      2011 Nov
# 57           International journal of nursing studies  21561619      2011 Nov
# 58  International journal of radiation oncology, b...  20933342   2011 Nov 01
# 59  International journal of radiation oncology, b...  20889265   2011 Nov 01
# 60           International journal of sports medicine  22052031      2011 Nov
#
#     pubyear                                   cleaned_abstract  \
# 0      2011  define value multislice computed tomography ct...
# 1      2011  assess feasibility mapping lumbar facet joints...
# 2      2011  intraosseous lipoma uncommon mesenchymal tumor...
# 3      2011  aim present work assess effectiveness scientif...
# 4      2011  prospective studies surgical outcomes survival...
# 5      2011  chronic pain impact psychological social facto...
# 6      2011  tnfalpha inflammatory mediator related neuropa...
# 7      2011  becoming increasingly evident people chronic r...
# 8      2011  gastrointestinal symptoms pain bloating nausea...
# 9      2011  clinical picture pituitary abscesses may resem...
# 10     2011  early fda gave approval new preparation gabape...
# 11     2011  hereditary angioedema relatively rare genetic ...
# 12     2011  acute chronic pain objective pharmacokinetic-p...
# 13     2011  huge unmet need novel medicines treatment chro...
# 14     2011  human pain biomarkers based standardized acute...
# 15     2011  trigeminal neuralgia tn persistent idiopathic ...
# 16     2011  working patients different chronic pain syndro...
# 17     2011  schwartz report tracks emerging trends affect ...
# 18     2011  prior research indicates primary care physicia...
# 19     2011  patients continue suffer severe disabling angi...
# 20     2011  cases meckel diverticulum md asymptomatic disc...
# 21     2011  authors present two cases mucocele appendix di...
# 22     2011  multicystic nephroma relatively rare tumor kid...
# 23     2011  unusual case chronic abdominal pain following ...
# 24     2011  indirect revascularization therapeutic approac...
# 25     2011  irritable bowel syndrome chronic uncontrollabl...
# 26     2011  background randomized trial compared endoscopi...
# 27     2011  background although proteases control inflamma...
# 28     2011  background intestinal microbiomes healthy chil...
# 29     2011  last years great many innovations introduced d...
# ..      ...                                                ...
# 31     2011  functional gastrointestinal disorders fgids ch...
# 32     2011  patients painful chronic pancreatitis cp incre...
# 33     2011  unexplained chest pain potentially attributabl...
# 34     2011  recent evidence suggests autonomic nervous sys...
# 35     2011  haemophilia patients experience acute pain joi...
# 36     2011  authors describe unique presentation celiac di...
# 37     2011  minimally invasive video-assisted thyroidectom...
# 38     2011  estimate -year prevalence headache repercussio...
# 39     2011  pattern-induced visual discomfort photophobia ...
# 40     2011  many children consider getting needle one fear...
# 41     2011  recognition sex differences symptom presentati...
# 42     2011  postural orthostatic tachycardia syndrome pots...
# 43     2011  naproxen non-steroidal anti-inflammatory drug ...
# 44     2011  endometriosis common gynecological diagnosis a...
# 45     2011  examined whether activation serotonergic desce...
# 46     2011  systemic sclerosis ssc multisystem disorder af...
# 47     2011  patients years age suspected hip fracture foll...
# 48     2011  patients orthopaedic trauma experience substan...
# 49     2011  psychological factors capable influencing indi...
# 50     2011  although non-selective non-steroidal anti-infl...
# 51     2011  non-steroidal anti-inflammatory drugs nsaids r...
# 52     2011  investigated changes characteristics neutrophi...
# 53     2011  flupirtine nonopioid analgesic without antipyr...
# 54     2011  post-herpetic neuralgia means pain occurs long...
# 55     2011  antipsychotic drugs clinical standard treatmen...
# 56     2011  sex race age disparities pain assessment treat...
# 57     2011  even though use gauge smaller quincke needle r...
# 58     2011  analyzed variables associated long-term toxici...
# 59     2011  correlate computed tomography ct imaging featu...
# 60     2011  rheumatoid arthritis ra one inflammatory kinds...
#
#                                  tokenized_c_abstract  \
# 0   [define, value, multislice, computed, tomograp...
# 1   [assess, feasibility, mapping, lumbar, facet, ...
# 2   [intraosseous, lipoma, uncommon, mesenchymal, ...
# 3   [aim, present, work, assess, effectiveness, sc...
# 4   [prospective, studies, surgical, outcomes, sur...
# 5   [chronic, pain, impact, psychological, social,...
# 6   [tnfalpha, inflammatory, mediator, related, ne...
# 7   [becoming, increasingly, evident, people, chro...
# 8   [gastrointestinal, symptoms, pain, bloating, n...
# 9   [clinical, picture, pituitary, abscesses, may,...
# 10  [early, fda, gave, approval, new, preparation,...
# 11  [hereditary, angioedema, relatively, rare, gen...
# 12  [acute, chronic, pain, objective, pharmacokine...
# 13  [huge, unmet, need, novel, medicines, treatmen...
# 14  [human, pain, biomarkers, based, standardized,...
# 15  [trigeminal, neuralgia, tn, persistent, idiopa...
# 16  [working, patients, different, chronic, pain, ...
# 17  [schwartz, report, tracks, emerging, trends, a...
# 18  [prior, research, indicates, primary, care, ph...
# 19  [patients, continue, suffer, severe, disabling...
# 20  [cases, meckel, diverticulum, md, asymptomatic...
# 21  [authors, present, two, cases, mucocele, appen...
# 22  [multicystic, nephroma, relatively, rare, tumo...
# 23  [unusual, case, chronic, abdominal, pain, foll...
# 24  [indirect, revascularization, therapeutic, app...
# 25  [irritable, bowel, syndrome, chronic, uncontro...
# 26  [background, randomized, trial, compared, endo...
# 27  [background, although, proteases, control, inf...
# 28  [background, intestinal, microbiomes, healthy,...
# 29  [last, years, great, many, innovations, introd...
# ..                                                ...
# 31  [functional, gastrointestinal, disorders, fgid...
# 32  [patients, painful, chronic, pancreatitis, cp,...
# 33  [unexplained, chest, pain, potentially, attrib...
# 34  [recent, evidence, suggests, autonomic, nervou...
# 35  [haemophilia, patients, experience, acute, pai...
# 36  [authors, describe, unique, presentation, celi...
# 37  [minimally, invasive, video, assisted, thyroid...
# 38  [estimate, year, prevalence, headache, repercu...
# 39  [pattern, induced, visual, discomfort, photoph...
# 40  [many, children, consider, getting, needle, on...
# 41  [recognition, sex, differences, symptom, prese...
# 42  [postural, orthostatic, tachycardia, syndrome,...
# 43  [naproxen, non, steroidal, anti, inflammatory,...
# 44  [endometriosis, common, gynecological, diagnos...
# 45  [examined, whether, activation, serotonergic, ...
# 46  [systemic, sclerosis, ssc, multisystem, disord...
# 47  [patients, years, age, suspected, hip, fractur...
# 48  [patients, orthopaedic, trauma, experience, su...
# 49  [psychological, factors, capable, influencing,...
# 50  [although, non, selective, non, steroidal, ant...
# 51  [non, steroidal, anti, inflammatory, drugs, ns...
# 52  [investigated, changes, characteristics, neutr...
# 53  [flupirtine, nonopioid, analgesic, without, an...
# 54  [post, herpetic, neuralgia, means, pain, occur...
# 55  [antipsychotic, drugs, clinical, standard, tre...
# 56  [sex, race, age, disparities, pain, assessment...
# 57  [even, though, use, gauge, smaller, quincke, n...
# 58  [analyzed, variables, associated, long, term, ...
# 59  [correlate, computed, tomography, ct, imaging,...
# 60  [rheumatoid, arthritis, ra, one, inflammatory,...
#
#                              cleaned_minimal_abstract  \
# 0   OBJECTIVE#NUM To define the value of multislic...
# 1   OBJECTIVES#NUM To assess the feasibility of T#...
# 2   Intraosseous lipoma is an uncommon mesenchymal...
# 3   OBJECTIVE#NUM Aim of the present work is to as...
# 4   PURPOSE#NUM There are few prospective studies ...
# 5   INTRODUCTION#NUM Chronic pain has an impact on...
# 6   PURPOSE#NUM TNFalpha is an inflammatory mediat...
# 7   It is becoming increasingly evident that peopl...
# 8   AIMS#NUM Gastrointestinal symptoms such as pai...
# 9   BACKGROUND#NUM The clinical picture of pituita...
# 10  INTRODUCTION#NUM In early #NUM#NUM the FDA gav...
# 11  Hereditary angioedema is a relatively rare gen...
# 12  In acute and chronic pain#NUM the objective of...
# 13  There is a huge unmet need for novel medicines...
# 14  Human pain biomarkers are based on standardize...
# 15  Trigeminal neuralgia #NUMTN#NUM and persistent...
# 16  Working with patients with different chronic p...
# 17  The Schwartz Report tracks emerging trends tha...
# 18  BACKGROUND AND OBJECTIVES#NUM Prior research i...
# 19  Patients who continue to suffer from severe an...
# 20  Most cases of Meckel#NUMs diverticulum #NUMMD#...
# 21  The authors present two cases of mucocele of t...
# 22  Multicystic nephroma is a relatively rare tumo...
# 23  This is an unusual case of chronic abdominal p...
# 24  BACKGROUND#NUM Indirect revascularization is a...
# 25  Irritable bowel syndrome is chronic#NUM uncont...
# 26  BACKGROUND #NUM AIMS#NUM A randomized trial th...
# 27  BACKGROUND #NUM AIMS#NUM Although proteases co...
# 28  BACKGROUND #NUM AIMS#NUM The intestinal microb...
# 29  Over the last #NUM years#NUM a great many inno...
# ..                                                ...
# 31  Functional gastrointestinal disorders #NUMFGID...
# 32  OBJECTIVE#NUM In patients with painful chronic...
# 33  INTRODUCTION#NUM Unexplained chest pain is pot...
# 34  BACKGROUND#NUM Recent evidence suggests that a...
# 35  Haemophilia patients experience acute pain dur...
# 36  The authors describe a unique presentation of ...
# 37  BACKGROUND#NUM Minimally invasive video-assist...
# 38  OBJECTIVES#NUM To estimate the #NUM-year preva...
# 39  BACKGROUND#NUM Pattern-induced visual discomfo...
# 40  UNLABELLED#NUM Many children consider getting ...
# 41  BACKGROUND#NUM Recognition of sex differences ...
# 42  BACKGROUND#NUM Postural orthostatic tachycardi...
# 43  Naproxen is a non-steroidal anti-inflammatory ...
# 44  BACKGROUND#NUM Endometriosis is the most commo...
# 45  AIM#NUM We examined whether activation of sero...
# 46  BACKGROUND#NUM Systemic sclerosis #NUMSSc#NUM ...
# 47  Patients over #NUM years of age with suspected...
# 48  INTRODUCTION#NUM Patients with orthopaedic tra...
# 49  Psychological factors are capable of influenci...
# 50  PURPOSE#NUM Although non-selective non-steroid...
# 51  Non-steroidal anti-inflammatory drugs #NUMNSAI...
# 52  We investigated the changes in characteristics...
# 53  INTRODUCTION#NUM Flupirtine#NUM a nonopioid an...
# 54  Post-herpetic neuralgia means pain which occur...
# 55  Antipsychotic drugs are the clinical standard ...
# 56  BACKGROUND#NUM Sex#NUM race#NUM and age dispar...
# 57  BACKGROUND#NUM Even though the use of a #NUM g...
# 58  PURPOSE#NUM We analyzed variables associated w...
# 59  PURPOSE#NUM To correlate computed tomography #...
# 60  Rheumatoid arthritis #NUMRA#NUM is one of the ...
#
#                                  tokenized_r_abstract  token_count_c_abstract  \
# 0   [OBJECTIVE, To, define, the, value, of, multis...                     130
# 1   [OBJECTIVES, To, assess, the, feasibility, of,...                     117
# 2   [Intraosseous, lipoma, is, an, uncommon, mesen...                      78
# 3   [OBJECTIVE, Aim, of, the, present, work, is, t...                      88
# 4   [PURPOSE, There, are, few, prospective, studie...                     165
# 5   [INTRODUCTION, Chronic, pain, has, an, impact,...                     190
# 6   [PURPOSE, TNFalpha, is, an, inflammatory, medi...                     153
# 7   [It, is, becoming, increasingly, evident, that...                     166
# 8   [AIMS, Gastrointestinal, symptoms, such, as, p...                     134
# 9   [BACKGROUND, The, clinical, picture, of, pitui...                      94
# 10  [INTRODUCTION, In, early, 2011, the, FDA, gave...                     105
# 11  [Hereditary, angioedema, is, a, relatively, ra...                      74
# 12  [In, acute, and, chronic, pain, the, objective...                     200
# 13  [There, is, a, huge, unmet, need, for, novel, ...                      39
# 14  [Human, pain, biomarkers, are, based, on, stan...                     116
# 15  [Trigeminal, neuralgia, TN, and, persistent, i...                     103
# 16  [Working, with, patients, with, different, chr...                      66
# 17  [The, Schwartz, Report, tracks, emerging, tren...                      28
# 18  [BACKGROUND, AND, OBJECTIVES, Prior, research,...                     158
# 19  [Patients, who, continue, to, suffer, from, se...                      81
# 20  [Most, cases, of, Meckel, s, diverticulum, MD,...                      52
# 21  [The, authors, present, two, cases, of, mucoce...                      54
# 22  [Multicystic, nephroma, is, a, relatively, rar...                      67
# 23  [This, is, an, unusual, case, of, chronic, abd...                      34
# 24  [BACKGROUND, Indirect, revascularization, is, ...                     158
# 25  [Irritable, bowel, syndrome, is, chronic, unco...                      99
# 26  [BACKGROUND, AIMS, A, randomized, trial, that,...                     152
# 27  [BACKGROUND, AIMS, Although, proteases, contro...                     177
# 28  [BACKGROUND, AIMS, The, intestinal, microbiome...                     169
# 29  [Over, the, last, 20, years, a, great, many, i...                      97
# ..                                                ...                     ...
# 31  [Functional, gastrointestinal, disorders, FGID...                     170
# 32  [OBJECTIVE, In, patients, with, painful, chron...                     167
# 33  [INTRODUCTION, Unexplained, chest, pain, is, p...                     173
# 34  [BACKGROUND, Recent, evidence, suggests, that,...                     191
# 35  [Haemophilia, patients, experience, acute, pai...                     126
# 36  [The, authors, describe, a, unique, presentati...                     106
# 37  [BACKGROUND, Minimally, invasive, video, assis...                     105
# 38  [OBJECTIVES, To, estimate, the, 1, year, preva...                     109
# 39  [BACKGROUND, Pattern, induced, visual, discomf...                     143
# 40  [UNLABELLED, Many, children, consider, getting...                     144
# 41  [BACKGROUND, Recognition, of, sex, differences...                      93
# 42  [BACKGROUND, Postural, orthostatic, tachycardi...                     118
# 43  [Naproxen, is, a, non, steroidal, anti, inflam...                     100
# 44  [BACKGROUND, Endometriosis, is, the, most, com...                     136
# 45  [AIM, We, examined, whether, activation, of, s...                     106
# 46  [BACKGROUND, Systemic, sclerosis, SSc, is, a, ...                     153
# 47  [Patients, over, 65, years, of, age, with, sus...                     142
# 48  [INTRODUCTION, Patients, with, orthopaedic, tr...                     157
# 49  [Psychological, factors, are, capable, of, inf...                     123
# 50  [PURPOSE, Although, non, selective, non, stero...                     165
# 51  [Non, steroidal, anti, inflammatory, drugs, NS...                     186
# 52  [We, investigated, the, changes, in, character...                     145
# 53  [INTRODUCTION, Flupirtine, a, nonopioid, analg...                     221
# 54  [Post, herpetic, neuralgia, means, pain, which...                      64
# 55  [Antipsychotic, drugs, are, the, clinical, sta...                     174
# 56  [BACKGROUND, Sex, race, and, age, disparities,...                     201
# 57  [BACKGROUND, Even, though, the, use, of, a, 25...                     229
# 58  [PURPOSE, We, analyzed, variables, associated,...                     167
# 59  [PURPOSE, To, correlate, computed, tomography,...                     167
# 60  [Rheumatoid, arthritis, RA, is, one, of, the, ...                     122
#
#     token_count_r_abstract  token_count_unq_c_abstract
# 0                      238                          83
# 1                      203                          72
# 2                      140                          64
# 3                      163                          62
# 4                      284                         115
# 5                      321                          99
# 6                      272                          98
# 7                      256                         102
# 8                      229                          92
# 9                      136                          76
# 10                     188                          81
# 11                     111                          56
# 12                     299                         136
# 13                      79                          34
# 14                     170                          83
# 15                     170                          80
# 16                     101                          59
# 17                      51                          28
# 18                     246                          74
# 19                     129                          65
# 20                      93                          46
# 21                     102                          50
# 22                      96                          56
# 23                      54                          31
# 24                     293                         115
# 25                     156                          70
# 26                     263                          94
# 27                     269                         104
# 28                     277                         129
# 29                     168                          84
# ..                     ...                         ...
# 31                     264                         122
# 32                     267                          93
# 33                     289                          96
# 34                     310                         106
# 35                     213                          77
# 36                     171                          85
# 37                     166                          81
# 38                     203                          76
# 39                     225                          77
# 40                     257                          93
# 41                     153                          63
# 42                     186                          95
# 43                     161                          77
# 44                     224                          92
# 45                     166                          85
# 46                     254                          97
# 47                     210                          93
# 48                     270                          88
# 49                     194                          77
# 50                     292                         100
# 51                     298                         122
# 52                     262                          67
# 53                     400                         143
# 54                     120                          44
# 55                     258                         108
# 56                     304                         124
# 57                     384                         106
# 58                     319                         113
# 59                     278                         102
# 60                     201                          81
#
# [61 rows x 13 columns]

# %%
#Test
print('Original Abstract: \n', papers.abstract[papers.pmid == test_pmid])
print('\nCleaned Abstract: \n', papers.loc[papers.pmid == test_pmid, CLEANED_ABSTRACT_COL])
print('\nTokenized Abstract: \n', papers.loc[papers.pmid == test_pmid, TOKENIZED_CLEAN_ABS_COL])
print('\nMinimally Processed Abstract: \n', papers.loc[papers.pmid == test_pmid, CLEANED_MINIMAL_ABSTRACT_COL])
papers[(papers.pmid == test_pmid)]
# Out:
# Original Abstract:
#  Series([], Name: abstract, dtype: object)
#
# Cleaned Abstract:
#  Series([], Name: cleaned_abstract, dtype: object)
#
# Tokenized Abstract:
#  Series([], Name: tokenized_c_abstract, dtype: object)
#
# Minimally Processed Abstract:
#  Series([], Name: cleaned_minimal_abstract, dtype: object)
# Empty DataFrame
# Columns: [abstract, articletitle, journaltitle, pmid, pubdate, pubyear, cleaned_abstract, tokenized_c_abstract, cleaned_minimal_abstract, tokenized_r_abstract, token_count_c_abstract, token_count_r_abstract, token_count_unq_c_abstract]
# Index: []

# %%
# Topic Modeling with LDA

# %%
## Create Corpus, Dictionary, and Related Text Constructs

# %%
# create a dictionary mapping words to ids
abstract_list = papers[TOKENIZED_CLEAN_ABS_COL].values
ca_gs_dictionary = corpora.Dictionary(abstract_list)

#remove extremes (similar to tf-idf)
ca_gs_dictionary.filter_extremes(no_below=1, no_above=0.8)
ca_gs_dictionary.compactify()

# %%
#convert the dictionary to a bag of words
ca_gs_corpus = [ca_gs_dictionary.doc2bow(words) for words in abstract_list]
# corpora.mmcorpus.MmCorpus.serialize('data/ca_gensim.mm', corpus)
ca_gs_tfidf = models.TfidfModel(ca_gs_corpus)

# %%
## Topic Modeling via LDA

# %%
### Determine optimal number of topics through coherence testing

# %%
def LDA_compute_coherence_values(dictionary, corpus, texts, limit):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(2, limit, 6):
        model = models.ldamulticore.LdaMulticore(corpus=corpus, num_topics=num_topics, id2word=dictionary, passes=5, 
                                                 workers=16)
        model_list.append(model)
        coherencemodel = models.CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
LDA_model_list, LDA_coherence_values = LDA_compute_coherence_values(dictionary=ca_gs_dictionary, corpus=ca_gs_corpus, texts=abstract_list, limit=50)

# %%
print(LDA_model_list)
print(LDA_coherence_values)
# Out:
# [<gensim.models.ldamulticore.LdaMulticore object at 0x7ffa1771ea90>, <gensim.models.ldamulticore.LdaMulticore object at 0x7ffa2ff9f0b8>, <gensim.models.ldamulticore.LdaMulticore object at 0x7ffa2c1b8dd8>, <gensim.models.ldamulticore.LdaMulticore object at 0x7ffa17ff66d8>, <gensim.models.ldamulticore.LdaMulticore object at 0x7ffa175f0f28>, <gensim.models.ldamulticore.LdaMulticore object at 0x7ffa2ffb0668>, <gensim.models.ldamulticore.LdaMulticore object at 0x7ffa177de0b8>, <gensim.models.ldamulticore.LdaMulticore object at 0x7ffa627e21d0>]
# [0.29692448213166944, 0.33159580753396034, 0.36143826089907172, 0.43876863147202638, 0.50484188608760516, 0.50166633383532089, 0.58967443987313306, 0.47987211682006597]

# %%
with open('LDA_model_list.pkl', 'wb') as f:
    pickle.dump(LDA_model_list, f)
    
with open('LDA_coherence_values.pkl', 'wb') as f:
    pickle.dump(LDA_coherence_values, f)

# %%
limit=50
x = range(2, limit, 6)
plt.plot(x, LDA_coherence_values)
plt.xlabel("Number of LDA Topics")
plt.ylabel("Coherence score")
# plt.legend(("LDA_coherence_values"), loc='best')
plt.show()

# %%
for m, cv in zip(x, LDA_coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.2969
# Num Topics = 8  has Coherence Value of 0.3316
# Num Topics = 14  has Coherence Value of 0.3614
# Num Topics = 20  has Coherence Value of 0.4388
# Num Topics = 26  has Coherence Value of 0.5048
# Num Topics = 32  has Coherence Value of 0.5017
# Num Topics = 38  has Coherence Value of 0.5897
# Num Topics = 44  has Coherence Value of 0.4799

# %%
num_of_LDA_topics = 25 #Derived from coherence testing of topic counts from 2 to 50 for LDA

# %%
### Run LDA with 25 topics

# %%
# %time lda = models.LdaModel(ca_gs_corpus, num_topics=num_of_LDA_topics, id2word =ca_gs_dictionary, update_every=5, passes=100)
# %time lda_mc = models.ldamulticore.LdaMulticore(corpus=ca_gs_corpus, num_topics=num_of_LDA_topics, id2word=ca_gs_dictionary, passes=100, workers=16)
# Out:
# CPU times: user 10.5 s, sys: 1.11 s, total: 11.6 s
# Wall time: 10.7 s

# %%
## Visualizing Topic clusters

# %%
from gensim.models.ldamodel import LdaModel
from gensim.corpora import Dictionary
from gensim.parsing.preprocessing import remove_stopwords, strip_punctuation

import numpy as np
import pandas as pd
import re

import plotly.offline as py
import plotly.graph_objs as go
import plotly.figure_factory as ff

py.init_notebook_mode()

from gensim.matutils import jensen_shannon
from scipy import spatial as scs
from scipy.cluster import hierarchy as sch
from scipy.spatial.distance import pdist, squareform
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
# get topic distributions
topic_dist = lda_mc.state.get_lambda()

# get topic terms
num_words = 300
topic_terms = [{w for (w, _) in lda_mc.show_topic(topic, topn=num_words)} for topic in range(topic_dist.shape[0])]

# no. of terms to display in annotation
n_ann_terms = 10

# use Jensen-Shannon distance metric in dendrogram
def js_dist(X):
    return pdist(X, lambda u, v: jensen_shannon(u, v))

# define method for distance calculation in clusters
linkagefun=lambda x: sch.linkage(x, 'single')

# calculate text annotations
def text_annotation(topic_dist, topic_terms, n_ann_terms, linkagefun):
    # get dendrogram hierarchy data
    linkagefun = lambda x: sch.linkage(x, 'single')
    d = js_dist(topic_dist)
    Z = linkagefun(d)
    P = sch.dendrogram(Z, orientation="bottom", no_plot=True)

    # store topic no.(leaves) corresponding to the x-ticks in dendrogram
    x_ticks = np.arange(5, len(P['leaves']) * 10 + 5, 10)
    x_topic = dict(zip(P['leaves'], x_ticks))

    # store {topic no.:topic terms}
    topic_vals = dict()
    for key, val in x_topic.items():
        topic_vals[val] = (topic_terms[key], topic_terms[key])

    text_annotations = []
    # loop through every trace (scatter plot) in dendrogram
    for trace in P['icoord']:
        fst_topic = topic_vals[trace[0]]
        scnd_topic = topic_vals[trace[2]]
        
        # annotation for two ends of current trace
        pos_tokens_t1 = list(fst_topic[0])[:min(len(fst_topic[0]), n_ann_terms)]
        neg_tokens_t1 = list(fst_topic[1])[:min(len(fst_topic[1]), n_ann_terms)]

        pos_tokens_t4 = list(scnd_topic[0])[:min(len(scnd_topic[0]), n_ann_terms)]
        neg_tokens_t4 = list(scnd_topic[1])[:min(len(scnd_topic[1]), n_ann_terms)]

        t1 = "<br>".join((": ".join(("+++", str(pos_tokens_t1))), ": ".join(("---", str(neg_tokens_t1)))))
        t2 = t3 = ()
        t4 = "<br>".join((": ".join(("+++", str(pos_tokens_t4))), ": ".join(("---", str(neg_tokens_t4)))))

        # show topic terms in leaves
        if trace[0] in x_ticks:
            t1 = str(list(topic_vals[trace[0]][0])[:n_ann_terms])
        if trace[2] in x_ticks:
            t4 = str(list(topic_vals[trace[2]][0])[:n_ann_terms])

        text_annotations.append([t1, t2, t3, t4])

        # calculate intersecting/diff for upper level
        intersecting = fst_topic[0] & scnd_topic[0]
        different = fst_topic[0].symmetric_difference(scnd_topic[0])

        center = (trace[0] + trace[2]) / 2
        topic_vals[center] = (intersecting, different)

        # remove trace value after it is annotated
        topic_vals.pop(trace[0], None)
        topic_vals.pop(trace[2], None)  
        
    return text_annotations

# %%
# get text annotations
annotation = text_annotation(topic_dist, topic_terms, n_ann_terms, linkagefun)

# Plot dendrogram
dendro = ff.create_dendrogram(topic_dist, distfun=js_dist, labels=range(1, 26), linkagefun=linkagefun, hovertext=annotation)
dendro['layout'].update({'width': 1000, 'height': 600})
py.iplot(dendro)
# Out:
# <div id="cec918ff-a331-46bf-a7b4-5ad61cc70179" style="height: 600px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cec918ff-a331-46bf-a7b4-5ad61cc70179", [{"type": "scatter", "x": [235.0, 235.0, 245.0, 245.0], "y": [0.0, 2.473825866378121e-10, 2.473825866378121e-10, 0.0], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['conclude', 'supplementation', 'ray', 'interview', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated']", [], [], "['conclude', 'supplementation', 'ray', 'interview', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y"}, {"type": "scatter", "x": [225.0, 225.0, 240.0, 240.0], "y": [0.0, 4.365575123621568e-10, 4.365575123621568e-10, 2.473825866378121e-10], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['conclude', 'supplementation', 'ray', 'interview', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated']", [], [], "+++: ['conclude', 'supplementation', 'ray', 'interview', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated']<br>---: ['failures', 'amygdala', 'cortex', 'disease', 'anisotropy', 'cp', 'patients', 'autonomic', 'activity', 'children']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y"}, {"type": "scatter", "x": [215.0, 215.0, 232.5, 232.5], "y": [0.0, 0.1515253782272339, 0.1515253782272339, 4.365575123621568e-10], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['conclude', 'ray', 'range', 'varied', 'markers', 'dual', 'mild', 'conditions', 'described', 'department']", [], [], "+++: ['conclude', 'supplementation', 'ray', 'interview', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated']<br>---: ['absenteeism', 'failures', 'consulting', 'discomfort', 'hemithyroidectomy', 'cp', 'cingulate', 'induced', 'inflammatory', 'grades']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y"}, {"type": "scatter", "x": [205.0, 205.0, 223.75, 223.75], "y": [0.0, 0.22495904564857483, 0.22495904564857483, 0.1515253782272339], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['supplementation', 'conclude', 'ray', 'ninety', 'varied', 'markers', 'dual', 'mild', 'narcotics', 'ami']", [], [], "+++: ['conclude', 'ray', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated', 'algorithmsprotocols', 'vagal']<br>---: ['described', 'clinical', 'immediately', 'body', 'records', 'physical', 'video', 'validity', 'thoracic', 'hit']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y"}, {"type": "scatter", "x": [195.0, 195.0, 214.375, 214.375], "y": [0.0, 0.25542259216308594, 0.25542259216308594, 0.22495904564857483], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['readsstool', 'conclude', 'learning', 'differences', 'irritable', 'markers', 'varied', 'dual', 'narcotics', 'neutrophil']", [], [], "+++: ['conclude', 'ray', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated', 'algorithmsprotocols', 'vagal']<br>---: ['supplementation', 'ninety', 'ami', 'psychometric', 'department', 'chronic', 'reconstruction', 'clinical', 'protocol', 'laboratory']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y"}, {"type": "scatter", "x": [185.0, 185.0, 204.6875, 204.6875], "y": [0.0, 0.269293874502182, 0.269293874502182, 0.25542259216308594], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['conclude', 'supplementation', 'brain', 'visceral', 'interview', 'brief', 'range', 'varied', 'markers', 'narcotics']", [], [], "+++: ['conclude', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated', 'algorithmsprotocols', 'vagal', 'adjusted']<br>---: ['readsstool', 'ray', 'neutrophil', 'randomforest', 'involved', 'clinical', 'met', 'genus', 'anatomically', 'analyzed']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y"}, {"type": "scatter", "x": [175.0, 175.0, 194.84375, 194.84 ...

# %%
# get text annotations
annotation = text_annotation(topic_dist, topic_terms, n_ann_terms, linkagefun)

# Initialize figure by creating upper dendrogram
figure = ff.create_dendrogram(topic_dist, distfun=js_dist, labels=range(1, 26), linkagefun=linkagefun, hovertext=annotation)
for i in range(len(figure['data'])):
    figure['data'][i]['yaxis'] = 'y2'

# %%
# get distance matrix and it's topic annotations
mdiff, annotation = lda_mc.diff(lda_mc, distance="jensen_shannon", normed=False)

# get reordered topic list
dendro_leaves = figure['layout']['xaxis']['ticktext']
dendro_leaves = [x - 1 for x in dendro_leaves]

# reorder distance matrix
heat_data = mdiff[dendro_leaves, :]
heat_data = heat_data[:, dendro_leaves]

# %%
# heatmap annotation
annotation_html = [["+++ {}<br>--- {}".format(", ".join(int_tokens), ", ".join(diff_tokens))
                    for (int_tokens, diff_tokens) in row] for row in annotation]

# plot heatmap of distance matrix
heatmap = go.Data([
    go.Heatmap(
        z=heat_data,
        colorscale='YIGnBu',
        text=annotation_html,
        hoverinfo='x+y+z+text'
    )
])

heatmap[0]['x'] = figure['layout']['xaxis']['tickvals']
heatmap[0]['y'] = figure['layout']['xaxis']['tickvals']

# Add Heatmap Data to Figure
figure['data'].extend(heatmap)

dendro_leaves = [x + 1 for x in dendro_leaves]

# Edit Layout
figure['layout'].update({'width': 800, 'height': 800,
                         'showlegend':False, 'hovermode': 'closest',
                         })

# Edit xaxis
figure['layout']['xaxis'].update({'domain': [.25, 1],
                                  'mirror': False,
                                  'showgrid': False,
                                  'showline': False,
                                  "showticklabels": True, 
                                  "tickmode": "array",
                                  "ticktext": dendro_leaves,
                                  "tickvals": figure['layout']['xaxis']['tickvals'],
                                  'zeroline': False,
                                  'ticks': ""})
# Edit yaxis
figure['layout']['yaxis'].update({'domain': [0, 0.75],
                                  'mirror': False,
                                  'showgrid': False,
                                  'showline': False,
                                  "showticklabels": True, 
                                  "tickmode": "array",
                                  "ticktext": dendro_leaves,
                                  "tickvals": figure['layout']['xaxis']['tickvals'],
                                  'zeroline': False,
                                  'ticks': ""})
# Edit yaxis2
figure['layout'].update({'yaxis2':{'domain': [0.75, 1],
                                   'mirror': False,
                                   'showgrid': False,
                                   'showline': False,
                                   'zeroline': False,
                                   'showticklabels': False,
                                   'ticks': ""}})

py.iplot(figure)
# Out:
# <div id="22b8bb82-a88f-45a8-a768-e0e4148ae498" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("22b8bb82-a88f-45a8-a768-e0e4148ae498", [{"type": "scatter", "x": [235.0, 235.0, 245.0, 245.0], "y": [0.0, 2.473825866378121e-10, 2.473825866378121e-10, 0.0], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['conclude', 'supplementation', 'ray', 'interview', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated']", [], [], "['conclude', 'supplementation', 'ray', 'interview', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y2"}, {"type": "scatter", "x": [225.0, 225.0, 240.0, 240.0], "y": [0.0, 4.365575123621568e-10, 4.365575123621568e-10, 2.473825866378121e-10], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['conclude', 'supplementation', 'ray', 'interview', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated']", [], [], "+++: ['conclude', 'supplementation', 'ray', 'interview', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated']<br>---: ['failures', 'amygdala', 'cortex', 'disease', 'anisotropy', 'cp', 'patients', 'autonomic', 'activity', 'children']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y2"}, {"type": "scatter", "x": [215.0, 215.0, 232.5, 232.5], "y": [0.0, 0.1515253782272339, 0.1515253782272339, 4.365575123621568e-10], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['conclude', 'ray', 'range', 'varied', 'markers', 'dual', 'mild', 'conditions', 'described', 'department']", [], [], "+++: ['conclude', 'supplementation', 'ray', 'interview', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated']<br>---: ['absenteeism', 'failures', 'consulting', 'discomfort', 'hemithyroidectomy', 'cp', 'cingulate', 'induced', 'inflammatory', 'grades']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y2"}, {"type": "scatter", "x": [205.0, 205.0, 223.75, 223.75], "y": [0.0, 0.22495904564857483, 0.22495904564857483, 0.1515253782272339], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['supplementation', 'conclude', 'ray', 'ninety', 'varied', 'markers', 'dual', 'mild', 'narcotics', 'ami']", [], [], "+++: ['conclude', 'ray', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated', 'algorithmsprotocols', 'vagal']<br>---: ['described', 'clinical', 'immediately', 'body', 'records', 'physical', 'video', 'validity', 'thoracic', 'hit']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y2"}, {"type": "scatter", "x": [195.0, 195.0, 214.375, 214.375], "y": [0.0, 0.25542259216308594, 0.25542259216308594, 0.22495904564857483], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['readsstool', 'conclude', 'learning', 'differences', 'irritable', 'markers', 'varied', 'dual', 'narcotics', 'neutrophil']", [], [], "+++: ['conclude', 'ray', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated', 'algorithmsprotocols', 'vagal']<br>---: ['supplementation', 'ninety', 'ami', 'psychometric', 'department', 'chronic', 'reconstruction', 'clinical', 'protocol', 'laboratory']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y2"}, {"type": "scatter", "x": [185.0, 185.0, 204.6875, 204.6875], "y": [0.0, 0.269293874502182, 0.269293874502182, 0.25542259216308594], "mode": "lines", "marker": {"color": "rgb(61,153,112)"}, "text": ["['conclude', 'supplementation', 'brain', 'visceral', 'interview', 'brief', 'range', 'varied', 'markers', 'narcotics']", [], [], "+++: ['conclude', 'varied', 'markers', 'dual', 'narcotics', 'mild', 'elevated', 'algorithmsprotocols', 'vagal', 'adjusted']<br>---: ['readsstool', 'ray', 'neutrophil', 'randomforest', 'involved', 'clinical', 'met', 'genus', 'anatomically', 'analyzed']"], "hoverinfo": "text", "xaxis": "x", "yaxis": "y2"}, {"type": "scatter", "x": [175.0, 175.0, 194.84375, 1 ...
